# %%
import datetime
import os
import time
import random

import numpy as np
import tensorflow as tf

from matplotlib import pyplot as plt
from tensorflow.keras import backend as K
from tensorflow.keras.layers import (Activation, BatchNormalization, Dense,
                                     Dropout, Flatten, Input, Reshape,
                                     TimeDistributed)
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import RMSprop

tf.compat.v1.disable_eager_execution()

# %%
# %load_ext tensorboard

# %%
import midi

# %%
NUM_EPOCHS = 100
LR = 0.001
WRITE_HISTORY = True
NUM_RAND_SONGS = 10
DO_RATE = 0.1
BN_M = 0.9

BATCH_SIZE = 256
MAX_LENGTH = 16
PARAM_SIZE = 120

np.random.seed(0)
random.seed(0)

# %%
y_samples = np.load('samples.npy')
y_lengths = np.load('lengths.npy')
num_songs = y_lengths.shape[0]

y_shape = (num_songs, MAX_LENGTH) + y_samples.shape[1:]
y_orig = np.zeros(y_shape, dtype=y_samples.dtype)

# %% [markdown]
# * y_samples = (_, 96, 96)
# * y_lengths = (238,)
# * y_shape = (238, 16, 96, 96)
# * y_origin = Array de zeros (238, 16, 96, 96)

# %%
cur_ix = 0
for i in range(num_songs):
    end_ix = cur_ix + y_lengths[i]
    for j in range(MAX_LENGTH):
        k = j % (end_ix - cur_ix) 
        y_orig[i,j] = y_samples[cur_ix + k]
    cur_ix = end_ix

# %%
y = np.copy(y_orig)

y_train = y[:125]
y_valid = y[125:]

y_test_song = np.copy(y[0])
midi.samples_to_midi(y_test_song, 'gt.mid', 16)

# %%
x_in = Input(shape=y_shape[1:])
x = Reshape((y_shape[1], -1))(x_in)
x = TimeDistributed(Dense(2000, activation='relu'))(x)
x = TimeDistributed(Dense(200, activation='relu'))(x)
x = Flatten()(x)
x = Dense(1600, activation='relu')(x)
x = Dense(PARAM_SIZE)(x)
x = BatchNormalization(momentum=BN_M, name='pre_encoder')(x)

x = Dense(1600, name='encoder')(x)
x = BatchNormalization(momentum=BN_M)(x)
x = Activation('relu')(x)
x = Dropout(DO_RATE)(x)
x = Dense(MAX_LENGTH * 200)(x)
x = Reshape((MAX_LENGTH, 200))(x)
x = TimeDistributed(BatchNormalization(momentum=BN_M))(x)
x = Activation('relu')(x)
x = Dropout(DO_RATE)(x)
x = TimeDistributed(Dense(2000))(x)
x = TimeDistributed(BatchNormalization(momentum=BN_M))(x)
x = Activation('relu')(x)
x = Dropout(DO_RATE)(x)
x = TimeDistributed(Dense(y_shape[2] * y_shape[3], activation='sigmoid'))(x)
x = Reshape((y_shape[1], y_shape[2], y_shape[3]))(x)

model = Model(x_in, x)
model.compile(optimizer=RMSprop(learning_rate=LR), loss='binary_crossentropy')

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 16, 96, 96)]      0
# _________________________________________________________________
# reshape (Reshape)            (None, 16, 9216)          0
# _________________________________________________________________
# time_distributed (TimeDistri (None, 16, 2000)          18434000
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 16, 200)           400200
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 200)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 3200)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1600)              5121600
# _________________________________________________________________
# dense_3 (Dense)              (None, 120)               192120
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 120)               0
# _________________________________________________________________
# encoder (Dense)              (None, 1600)              193600
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1600)              6400
# _________________________________________________________________
# activation (Activation)      (None, 1600)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1600)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 3200)              5123200
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 16, 200)           0
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 16, 200)           800
# _________________________________________________________________
# activation_1 (Activation)    (None, 16, 200)           0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 16, 200)           0
# _________________________________________________________________
# time_distributed_3 (TimeDist (None, 16, 2000)          402000
# _________________________________________________________________
# time_distributed_4 (TimeDist (None, 16, 2000)          8000
# _________________________________________________________________
# activation_2 (Activation)    (None, 16, 2000)          0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 16, 2000)          0
# _________________________________________________________________
# time_distributed_5 (TimeDist (None, 16, 9216)          18441216
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 16, 96, 96)        0
# =================================================================
# Total params: 48,323,136
# Trainable params: 48,315,536
# Non-trainable params: 7,600
# _________________________________________________________________

# %%
func = K.function([model.get_layer('encoder').input, K.learning_phase()], [model.layers[-1].output])
enc = Model(inputs=model.input, outputs=model.get_layer('pre_encoder').output)

# %%
rand_vecs = np.random.normal(0.0, 1.0, (NUM_RAND_SONGS, PARAM_SIZE))
np.save('rand.npy', rand_vecs)

# %%
def make_rand_songs(write_dir, rand_vecs):
    for i in range(rand_vecs.shape[0]):
        x_rand = rand_vecs[i:i+1]
        y_song = func([x_rand, 0])[0]
        midi.samples_to_midi(y_song[0], write_dir + 'rand' + str(i) + '.mid', 16, 0.25)

def make_rand_songs_normalized(write_dir, rand_vecs):
    x_enc = np.squeeze(enc.predict(y_orig))

    x_mean = np.mean(x_enc, axis=0)
    x_cov = np.cov((x_enc - x_mean).T)
    _, s, v = np.linalg.svd(x_cov)
    e = np.sqrt(s)

    print(f"Means: {x_mean[:6]}")
    print(f"Evals: {e[:6]} ")

    x_vecs = x_mean + np.dot(rand_vecs * e, v)
    make_rand_songs(write_dir, x_vecs)

# %%
log_dir = os.path.join(
    "logs",
    datetime.datetime.now().strftime("%Y%m%d-%H%M%S"),
)
callbacks = [
    tf.keras.callbacks.TensorBoard(log_dir=log_dir),
]

# %%
# def create_model():
#     def rounded_accuracy(y_true, y_pred):
#         return tf.keras.metrics.binary_accuracy(
#             tf.round(y_true),
#             tf.round(y_pred),
#         )
    
#     stacked_encoder = tf.keras.models.Sequential([
#         Input(shape=(16,96,96)),
#         Reshape((16, -1)),
#         TimeDistributed(Dense(2000, activation='relu')),
#         TimeDistributed(Dense(200, activation='relu')),
#         Flatten(),
#         Dense(1600, activation='relu'),
#         Dense(PARAM_SIZE),
#         BatchNormalization(momentum=BN_M, name='pre_encoder')
#     ])
#     stacked_decoder = tf.keras.models.Sequential([
#         Dense(1600, name='encoder'),
#         BatchNormalization(momentum=BN_M),
#         Activation('relu'),
#         Dense(MAX_LENGTH * 200),
#         Reshape((MAX_LENGTH, 200)),
#         TimeDistributed(BatchNormalization(momentum=BN_M)),
#         Activation('relu'),
#         TimeDistributed(Dense(2000)),
#         TimeDistributed(BatchNormalization(momentum=BN_M)),
#         Activation('relu'),
#         TimeDistributed(Dense(96 * 96, activation='sigmoid')),
#         Reshape((16,96,96))
#     ])
#     stacked_ae = tf.keras.models.Sequential([stacked_encoder, stacked_decoder])

#     stacked_ae.compile(
#         loss="binary_crossentropy",
#         optimizer= RMSprop(learning_rate=LR),
#         metrics=[rounded_accuracy],
#     )

#     return stacked_encoder, stacked_decoder, stacked_ae

# stacked_encoder, stacked_decoder, model = create_model()

# %%
history = model.fit(
    y_train,
    y_train,
    epochs=NUM_EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(y_valid, y_valid),
    callbacks=callbacks,
    verbose=2,
)

loss = history.history["loss"][-1]
print(f"Train Loss: {loss}")

write_dir = 'History/'
model.save('History/model.h5')
# Out:
# Train on 125 samples, validate on 113 samples
# Epoch 1/100
# C:\Users\eller\anaconda3\envs\IC\lib\site-packages\keras\engine\training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 125/125 - 2s - loss: 0.7153 - rounded_accuracy: 0.4979 - val_loss: 0.6535 - val_rounded_accuracy: 0.9960
# Epoch 2/100
# 125/125 - 0s - loss: 0.2126 - rounded_accuracy: 0.9966 - val_loss: 0.6061 - val_rounded_accuracy: 0.9959
# Epoch 3/100
# 125/125 - 0s - loss: 0.0698 - rounded_accuracy: 0.9966 - val_loss: 0.4963 - val_rounded_accuracy: 0.9959
# Epoch 4/100
# 125/125 - 0s - loss: 0.0624 - rounded_accuracy: 0.9966 - val_loss: 0.5057 - val_rounded_accuracy: 0.9960
# Epoch 5/100
# 125/125 - 0s - loss: 0.0570 - rounded_accuracy: 0.9966 - val_loss: 0.3432 - val_rounded_accuracy: 0.9960
# Epoch 6/100
# 125/125 - 0s - loss: 0.0346 - rounded_accuracy: 0.9966 - val_loss: 0.3498 - val_rounded_accuracy: 0.9960
# Epoch 7/100
# 125/125 - 0s - loss: 0.0287 - rounded_accuracy: 0.9966 - val_loss: 0.2974 - val_rounded_accuracy: 0.9960
# Epoch 8/100
# 125/125 - 0s - loss: 0.0258 - rounded_accuracy: 0.9966 - val_loss: 0.2836 - val_rounded_accuracy: 0.9960
# Epoch 9/100
# 125/125 - 0s - loss: 0.0241 - rounded_accuracy: 0.9966 - val_loss: 0.2502 - val_rounded_accuracy: 0.9960
# Epoch 10/100
# 125/125 - 0s - loss: 0.0229 - rounded_accuracy: 0.9966 - val_loss: 0.2252 - val_rounded_accuracy: 0.9960
# Epoch 11/100
# 125/125 - 0s - loss: 0.0219 - rounded_accuracy: 0.9966 - val_loss: 0.2002 - val_rounded_accuracy: 0.9960
# Epoch 12/100
# 125/125 - 0s - loss: 0.0211 - rounded_accuracy: 0.9966 - val_loss: 0.1762 - val_rounded_accuracy: 0.9960
# Epoch 13/100
# 125/125 - 0s - loss: 0.0205 - rounded_accuracy: 0.9966 - val_loss: 0.1559 - val_rounded_accuracy: 0.9960
# Epoch 14/100
# 125/125 - 0s - loss: 0.0200 - rounded_accuracy: 0.9966 - val_loss: 0.1364 - val_rounded_accuracy: 0.9960
# Epoch 15/100
# 125/125 - 0s - loss: 0.0195 - rounded_accuracy: 0.9966 - val_loss: 0.1201 - val_rounded_accuracy: 0.9960
# Epoch 16/100
# 125/125 - 0s - loss: 0.0191 - rounded_accuracy: 0.9966 - val_loss: 0.1052 - val_rounded_accuracy: 0.9960
# Epoch 17/100
# 125/125 - 0s - loss: 0.0188 - rounded_accuracy: 0.9966 - val_loss: 0.0928 - val_rounded_accuracy: 0.9960
# Epoch 18/100
# 125/125 - 0s - loss: 0.0184 - rounded_accuracy: 0.9966 - val_loss: 0.0816 - val_rounded_accuracy: 0.9960
# Epoch 19/100
# 125/125 - 0s - loss: 0.0182 - rounded_accuracy: 0.9966 - val_loss: 0.0724 - val_rounded_accuracy: 0.9960
# Epoch 20/100
# 125/125 - 0s - loss: 0.0179 - rounded_accuracy: 0.9966 - val_loss: 0.0642 - val_rounded_accuracy: 0.9960
# Epoch 21/100
# 125/125 - 0s - loss: 0.0177 - rounded_accuracy: 0.9966 - val_loss: 0.0576 - val_rounded_accuracy: 0.9960
# Epoch 22/100
# 125/125 - 0s - loss: 0.0175 - rounded_accuracy: 0.9966 - val_loss: 0.0517 - val_rounded_accuracy: 0.9960
# Epoch 23/100
# 125/125 - 0s - loss: 0.0173 - rounded_accuracy: 0.9966 - val_loss: 0.0468 - val_rounded_accuracy: 0.9960
# Epoch 24/100
# 125/125 - 0s - loss: 0.0172 - rounded_accuracy: 0.9966 - val_loss: 0.0426 - val_rounded_accuracy: 0.9960
# Epoch 25/100
# 125/125 - 0s - loss: 0.0170 - rounded_accuracy: 0.9966 - val_loss: 0.0391 - val_rounded_accuracy: 0.9960
# Epoch 26/100
# 125/125 - 0s - loss: 0.0169 - rounded_accuracy: 0.9966 - val_loss: 0.0360 - val_rounded_accuracy: 0.9960
# Epoch 27/100
# 125/125 - 0s - loss: 0.0167 - rounded_accuracy: 0.9966 - val_loss: 0.0337 - val_rounded_accuracy: 0.9960
# Epoch 28/100
# 125/125 - 0s - loss: 0.0166 - rounded_accuracy: 0.9966 - val_loss: 0.0312 - val_rounded_accuracy: 0.9960
# Epoch 29/100
# 125/125 - 0s - loss: 0.0165 - rounded_accuracy: 0.9966 - val_loss: 0.0298 - val_rounded_accuracy: 0.9960
# Epoch 30/100
# 125/125 - 0s - loss: 0.0164 - rounded_accuracy: 0.9966 - val_loss: 0.0272 - val_rounded_accuracy: 0.9960
# Epoch 31/100
# 125/125 - 0s - loss: 0.0163 - rounded_accuracy: 0.9966 - val_loss: 0.0271 - val_rounded_accuracy: 0.9960
# Epoch 32/100
# 125/125 - 0s - loss: 0.0162 - rounded_accuracy: 0.9966 - val_loss: 0.0235 - val_rounded_accuracy: 0.9960
# Epoch 33/100
# 125/125 - 0s - loss: 0.0161 - rounded_accuracy: 0.9966 - val_loss: 0.0250 - val_rounded_accuracy: 0.9960
# Epoch 34/100
# 125/125 - 0s - loss: 0.0160 - rounded_accuracy: 0.9966 - val_loss: 0.0221 - val_rounded_accuracy: 0.9960
# Epoch 35/100
# 125/125 - 0s - loss: 0.0160 - rounded_accuracy: 0.9966 - val_loss: 0.0241 - val_rounded_accuracy: 0.9960
# Epoch 36/100
# 125/125 - 0s - loss: 0.0159 - rounded_accuracy: 0.9966 - val_loss: 0.0212 - val_rounded_accuracy: 0.9960
# Epoch 37/100
# 125/125 - 0s - loss: 0.0159 - rounded_accuracy: 0.9966 - val_loss: 0.0231 - val_rounded_accuracy: 0.9960
# Epoch 38/100
# 125/125 - 0s - loss: 0.0157 - rounded_accuracy: 0.9966 - val_loss: 0.0212 - val_rounded_accuracy: 0.9960
# Epoch 39/100
# 125/125 - 0s - loss: 0.0158 - rounded_accuracy: 0.9966 - val_loss: 0.0232 - val_rounded_accuracy: 0.9960
# Epoch 40/100
# 125/125 - 0s - loss: 0.0155 - rounded_accuracy: 0.9966 - val_loss: 0.0209 - val_rounded_accuracy: 0.9960
# Epoch 41/100
# 125/125 - 0s - loss: 0.0156 - rounded_accuracy: 0.9966 - val_loss: 0.0222 - val_rounded_accuracy: 0.9960
# Epoch 42/100
# 125/125 - 0s - loss: 0.0153 - rounded_accuracy: 0.9966 - val_loss: 0.0207 - val_rounded_accuracy: 0.9960
# Epoch 43/100
# 125/125 - 0s - loss: 0.0154 - rounded_accuracy: 0.9966 - val_loss: 0.0213 - val_rounded_accuracy: 0.9960
# Epoch 44/100
# 125/125 - 0s - loss: 0.0152 - rounded_accuracy: 0.9966 - val_loss: 0.0203 - val_rounded_accuracy: 0.9960
# Epoch 45/100
# 125/125 - 0s - loss: 0.0152 - rounded_accuracy: 0.9966 - val_loss: 0.0205 - val_rounded_accuracy: 0.9960
# Epoch 46/100
# 125/125 - 0s - loss: 0.0150 - rounded_accuracy: 0.9966 - val_loss: 0.0198 - val_rounded_accuracy: 0.9960
# Epoch 47/100
# 125/125 - 0s - loss: 0.0151 - rounded_accuracy: 0.9966 - val_loss: 0.0200 - val_rounded_accuracy: 0.9960
# Epoch 48/100
# 125/125 - 0s - loss: 0.0148 - rounded_accuracy: 0.9966 - val_loss: 0.0198 - val_rounded_accuracy: 0.9960
# Epoch 49/100
# 125/125 - 0s - loss: 0.0149 - rounded_accuracy: 0.9966 - val_loss: 0.0201 - val_rounded_accuracy: 0.9960
# Epoch 50/100
# 125/125 - 0s - loss: 0.0147 - rounded_accuracy: 0.9966 - val_loss: 0.0198 - val_rounded_accuracy: 0.9960
# Epoch 51/100
# 125/125 - 0s - loss: 0.0148 - rounded_accuracy: 0.9966 - val_loss: 0.0200 - val_rounded_accuracy: 0.9959
# Epoch 52/100
# 125/125 - 0s - loss: 0.0145 - rounded_accuracy: 0.9966 - val_loss: 0.0197 - val_rounded_accuracy: 0.9960
# Epoch 53/100
# 125/125 - 0s - loss: 0.0146 - rounded_accuracy: 0.9966 - val_loss: 0.0191 - val_rounded_accuracy: 0.9959
# Epoch 54/100
# 125/125 - 0s - loss: 0.0143 - rounded_accuracy: 0.9966 - val_loss: 0.0198 - val_rounded_accuracy: 0.9960
# Epoch 55/100
# 125/125 - 0s - loss: 0.0144 - rounded_accuracy: 0.9966 - val_loss: 0.0191 - val_rounded_accuracy: 0.9959
# Epoch 56/100
# 125/125 - 0s - loss: 0.0141 - rounded_accuracy: 0.9966 - val_loss: 0.0195 - val_rounded_accuracy: 0.9960
# Epoch 57/100
# 125/125 - 0s - loss: 0.0141 - rounded_accuracy: 0.9966 - val_loss: 0.0193 - val_rounded_accuracy: 0.9960
# Epoch 58/100
# 125/125 - 0s - loss: 0.0138 - rounded_accuracy: 0.9967 - val_loss: 0.0197 - val_rounded_accuracy: 0.9960
# Epoch 59/100
# 125/125 - 0s - loss: 0.0139 - rounded_accuracy: 0.9966 - val_loss: 0.0193 - val_rounded_accuracy: 0.9960
# Epoch 60/100
# 125/125 - 0s - loss: 0.0136 - rounded_accuracy: 0.9967 - val_loss: 0.0199 - val_rounded_accuracy: 0.9960
# Epoch 61/100
# 125/125 - 0s - loss: 0.0135 - rounded_accuracy: 0.9966 - val_loss: 0.0196 - val_rounded_accuracy: 0.9960
# Epoch 62/100
# 125/125 - 0s - loss: 0.0132 - rounded_accuracy: 0.9967 - val_loss: 0.0198 - val_rounded_accuracy: 0.9960
# Epoch 63/100
# 125/125 - 0s - loss: 0.0132 - rounded_accuracy: 0.9966 - val_loss: 0.0194 - val_rounded_accuracy: 0.9960
# Epoch 64/100
# 125/125 - 0s - loss: 0.0130 - rounded_accuracy: 0.9967 - val_loss: 0.0195 - val_rounded_accuracy: 0.9960
# Epoch 65/100
# 125/125 - 0s - loss: 0.0130 - rounded_accuracy: 0.9966 - val_loss: 0.0196 - val_rounded_accuracy: 0.9959
# Epoch 66/100
# 125/125 - 0s - loss: 0.0128 - rounded_accuracy: 0.9967 - val_loss: 0.0199 - val_rounded_accuracy: 0.9960
# Epoch 67/100
# 125/125 - 0s - loss: 0.0127 - rounded_accuracy: 0.9967 - val_loss: 0.0192 - val_rounded_accuracy: 0.9960
# Epoch 68/100
# 125/125 - 0s - loss: 0.0124 - rounded_accuracy: 0.9967 - val_loss: 0.0191 - val_rounded_accuracy: 0.9960
# Epoch 69/100
# 125/125 - 0s - loss: 0.0120 - rounded_accuracy: 0.9967 - val_loss: 0.0192 - val_rounded_accuracy: 0.9960
# Epoch 70/100
# 125/125 - 0s - loss: 0.0118 - rounded_accuracy: 0.9968 - val_loss: 0.0196 - val_rounded_accuracy: 0.9960
# Epoch 71/100
# 125/125 - 0s - loss: 0.0117 - rounded_accuracy: 0.9968 - val_loss: 0.0202 - val_rounded_accuracy: 0.9958
# Epoch 72/100
# 125/125 - 0s - loss: 0.0118 - rounded_accuracy: 0.9968 - val_loss: 0.0202 - val_rounded_accuracy: 0.9960
# Epoch 73/100
# 125/125 - 0s - loss: 0.0120 - rounded_accuracy: 0.9967 - val_loss: 0.0197 - val_rounded_accuracy: 0.9960
# Epoch 74/100
# 125/125 - 0s - loss: 0.0115 - rounded_accuracy: 0.9969 - val_loss: 0.0192 - val_rounded_accuracy: 0.9960
# Epoch 75/100
# 125/125 - 0s - loss: 0.0113 - rounded_accuracy: 0.9968 - val_loss: 0.0192 - val_rounded_accuracy: 0.9960
# Epoch 76/100
# 125/125 - 0s - loss: 0.0109 - rounded_accuracy: 0.9970 - val_loss: 0.0196 - val_rounded_accuracy: 0.9960
# Epoch 77/100
# 125/125 - 0s - loss: 0.0108 - rounded_accuracy: 0.9969 - val_loss: 0.0192 - val_rounded_accuracy: 0.9960
# Epoch 78/100
# 125/125 - 0s - loss: 0.0106 - rounded_accuracy: 0.9970 - val_loss: 0.0194 - val_rounded_accuracy: 0.9960
# Epoch 79/100
# 125/125 - 0s - loss: 0.0104 - rounded_accuracy: 0.9969 - val_loss: 0.0188 - val_rounded_accuracy: 0.9960
# Epoch 80/100
# 125/125 - 0s - loss: 0.0100 - rounded_accuracy: 0.9971 - val_loss: 0.0194 - val_rounded_accuracy: 0.9960
# Epoch 81/100
# 125/125 - 0s - loss: 0.0100 - rounded_accuracy: 0.9970 - val_loss: 0.0188 - val_rounded_accuracy: 0.9960
# Epoch 82/100
# 125/125 - 0s - loss: 0.0099 - rounded_accuracy: 0.9972 - val_loss: 0.0201 - val_rounded_accuracy: 0.9960
# Epoch 83/100
# 125/125 - 0s - loss: 0.0099 - rounded_accuracy: 0.9969 - val_loss: 0.0187 - val_rounded_accuracy: 0.9960
# Epoch 84/100
# 125/125 - 0s - loss: 0.0095 - rounded_accuracy: 0.9973 - val_loss: 0.0201 - val_rounded_accuracy: 0.9960
# Epoch 85/100
# 125/125 - 0s - loss: 0.0093 - rounded_accuracy: 0.9970 - val_loss: 0.0188 - val_rounded_accuracy: 0.9959
# Epoch 86/100
# 125/125 - 0s - loss: 0.0090 - rounded_accuracy: 0.9974 - val_loss: 0.0200 - val_rounded_accuracy: 0.9960
# Epoch 87/100
# 125/125 - 0s - loss: 0.0090 - rounded_accuracy: 0.9971 - val_loss: 0.0188 - val_rounded_accuracy: 0.9960
# Epoch 88/100
# 125/125 - 0s - loss: 0.0088 - rounded_accuracy: 0.9974 - val_loss: 0.0194 - val_rounded_accuracy: 0.9960
# Epoch 89/100
# 125/125 - 0s - loss: 0.0087 - rounded_accuracy: 0.9972 - val_loss: 0.0192 - val_rounded_accuracy: 0.9959
# Epoch 90/100
# 125/125 - 0s - loss: 0.0084 - rounded_accuracy: 0.9974 - val_loss: 0.0188 - val_rounded_accuracy: 0.9960
# Epoch 91/100
# 125/125 - 0s - loss: 0.0082 - rounded_accuracy: 0.9973 - val_loss: 0.0191 - val_rounded_accuracy: 0.9959
# Epoch 92/100
# 125/125 - 0s - loss: 0.0079 - rounded_accuracy: 0.9975 - val_loss: 0.0189 - val_rounded_accuracy: 0.9960
# Epoch 93/100
# 125/125 - 0s - loss: 0.0079 - rounded_accuracy: 0.9974 - val_loss: 0.0192 - val_rounded_accuracy: 0.9960
# Epoch 94/100
# 125/125 - 0s - loss: 0.0079 - rounded_accuracy: 0.9976 - val_loss: 0.0198 - val_rounded_accuracy: 0.9959
# Epoch 95/100
# 125/125 - 0s - loss: 0.0080 - rounded_accuracy: 0.9975 - val_loss: 0.0199 - val_rounded_accuracy: 0.9960
# Epoch 96/100
# 125/125 - 0s - loss: 0.0076 - rounded_accuracy: 0.9976 - val_loss: 0.0188 - val_rounded_accuracy: 0.9960
# Epoch 97/100
# 125/125 - 0s - loss: 0.0072 - rounded_accuracy: 0.9977 - val_loss: 0.0189 - val_rounded_accuracy: 0.9960
# Epoch 98/100
# 125/125 - 0s - loss: 0.0068 - rounded_accuracy: 0.9979 - val_loss: 0.0186 - val_rounded_accuracy: 0.9960
# Epoch 99/100
# 125/125 - 0s - loss: 0.0066 - rounded_accuracy: 0.9979 - val_loss: 0.0189 - val_rounded_accuracy: 0.9960
# Epoch 100/100
# 125/125 - 0s - loss: 0.0064 - rounded_accuracy: 0.9981 - val_loss: 0.0188 - val_rounded_accuracy: 0.9960
# Train Loss: 0.006433566566556692

# %%
y_song = model.predict((y_test_song).reshape(1,16,96,96), batch_size=BATCH_SIZE)

midi.samples_to_midi(y_song[0], write_dir + 'test.mid', 16)
make_rand_songs_normalized(write_dir, rand_vecs)
# Out:
# Means: [ 0.01421444  0.01081225 -0.04106295  0.02704114 -0.04220293  0.02202534]
# Evals: [0.14756089 0.07668684 0.07389737 0.07114887 0.0695562  0.06809989]

# %%
# %tensorboard --logdir logs
# Out:
# Reusing TensorBoard on port 6006 (pid 10056), started 0:25:05 ago. (Use '!kill 10056' to kill it.)
#       <iframe id="tensorboard-frame-629f6fbed82c07cd" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-629f6fbed82c07cd");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
